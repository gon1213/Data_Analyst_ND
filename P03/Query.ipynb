# %%
import sqlite3
import sys
import csv
from pprint import pprint
from collections import defaultdict

# %% [markdown]
# # San Jose
# #### From Open Street Map

# %% [markdown]
# ## create and connect database

# %%
sqlite_file = "openstreetmap.db"
conn = sqlite3.connect(sqlite_file)

# %% [markdown]
# ## insert csv file into database

# %%
cur = conn.cursor()
with open('nodes_tags.csv','rb') as fin1:
    dr1 = csv.DictReader(fin1) 
    to_nodes_tags = [(i['id'].decode("utf-8"), i['key'].decode("utf-8"),i['value'].decode("utf-8"),
                      i['type'].decode("utf-8")) 
                     for i in dr1]
    
with open('nodes.csv','rb') as fin2:
    dr2 = csv.DictReader(fin2) 
    to_nodes = [(i['id'].decode("utf-8"), i['user'].decode("utf-8"),i['uid'].decode("utf-8"),
                 i['version'].decode("utf-8"),  i['lat'].decode("utf-8"), i['lon'].decode("utf-8"), 
                 i['changeset'].decode("utf-8"), i['timestamp'].decode("utf-8")) 
                     for i in dr2]
    
with open('ways.csv','rb') as fin3:
    dr3 = csv.DictReader(fin3) 
    to_ways = [(i['id'].decode("utf-8"), i['user'].decode("utf-8"),i['uid'].decode("utf-8"),
                i['version'].decode("utf-8"),  i['changeset'].decode("utf-8"), i['timestamp'].decode("utf-8")) 
                     for i in dr3]
    
with open('ways_tags.csv','rb') as fin4:
    dr4 = csv.DictReader(fin4) 
    to_ways_tags = [(i['id'].decode("utf-8"), i['key'].decode("utf-8"),i['value'].decode("utf-8"), i['type'].decode("utf-8")) 
                     for i in dr4]
    
with open('ways_nodes.csv','rb') as fin5:
    dr5 = csv.DictReader(fin5) 
    to_ways_nodes = [(i['id'].decode("utf-8"), i['node_id'].decode("utf-8"),i['position'].decode("utf-8")) 
                     for i in dr5]
    
cur.executemany("INSERT INTO nodes_tags(id, key, value,type) VALUES (?, ?, ?, ?);", to_nodes_tags)
cur.executemany("INSERT INTO nodes(id, user, uid, version,lat,lon, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?, ?, ?);", to_nodes)
cur.executemany("INSERT INTO way(id, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?);", to_ways)
cur.executemany("INSERT INTO ways_tags(id, key, value,type) VALUES (?, ?, ?, ?);", to_ways_tags)
cur.executemany("INSERT INTO ways_nodes(id, node_id, position) VALUES (?, ?, ?);", to_ways_nodes)

conn.commit()
conn.close()

# %% [markdown]
# ## count entries for each file

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute('''SELECT COUNT(*) FROM nodes
            ''')
output1=cur.fetchall()


cur.execute('''SELECT COUNT(*) FROM nodes_tags
            ''')
output2=cur.fetchall()

cur.execute('''SELECT COUNT(*) FROM way
            ''')
output3=cur.fetchall()

cur.execute('''SELECT COUNT(*) FROM ways_tags
            ''')
output4=cur.fetchall()

cur.execute('''SELECT COUNT(*) FROM ways_nodes
            ''')
output5=cur.fetchall()

print "nodes's data: ", output1[0][0]
print "nodes_tags's data: " , output2[0][0]
print "way's data: " , output3[0][0]
print "ways_tags's data: " , output4[0][0]
print "ways_nodes's data: " , output5[0][0]
conn.commit()
conn.close()
# Out:
# nodes's data:  1276635
# nodes_tags's data:  66320
# way's data:  169712
# ways_tags's data:  615127
# ways_nodes's data:  1491733

# %% [markdown]
# ## Unique users and Top Ten contributing users

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute('''SELECT COUNT(DISTINCT(M.uid))
                FROM (  SELECT uid FROM nodes
                        UNION ALL
                        SELECT uid FROM way) M
            ''')
output=cur.fetchall()
print "Total unique users: ", output[0][0],"\n"
cur.execute('''SELECT uid, user, COUNT(uid) AS nums
            FROM nodes
            GROUP BY uid
            ORDER BY nums DESC
            limit 10
            ''')
output=cur.fetchall()
print "Top Ten contributing users:\n"
for row in output:
    print "id: ",row[0] , ", User Name: ", row[1], ", Edited times: ", row[2]
conn.commit()
conn.close()
# Out:
# Total unique users:  1186
#
# Top Ten contributing users:
#
# id:  55774 , User Name:  nmixter , Edited times:  252497
# id:  201724 , User Name:  mk408 , Edited times:  143696
# id:  74705 , User Name:  Bike Mapper , Edited times:  71701
# id:  2512300 , User Name:  samely , Edited times:  68396
# id:  2226712 , User Name:  dannykath , Edited times:  66277
# id:  2219338 , User Name:  RichRico , Edited times:  63673
# id:  2748195 , User Name:  karitotp , Edited times:  51835
# id:  318696 , User Name:  n76 , Edited times:  31278
# id:  595221 , User Name:  matthieun , Edited times:  28199
# id:  33757 , User Name:  Minh Nguyen , Edited times:  27496

# %% [markdown]
# ## Top 5 version used

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute('''SELECT version, COUNT(version) AS nums
            FROM nodes
            GROUP BY version
            ORDER BY nums DESC
            limit 5
            ''')
output=cur.fetchall()
for row in output:
    print "version " , row[0], ", number :", row[1]
conn.commit()
conn.close()
# Out:
# version  1 , number : 991878
# version  2 , number : 171662
# version  3 , number : 46053
# version  4 , number : 27034
# version  5 , number : 16727

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute('''SELECT version, COUNT(version) AS nums
            FROM nodes
            WHERE user="nmixter"
            GROUP BY version
            ORDER BY nums DESC
            limit 5
            ''')
output=cur.fetchall()
for row in output:
    print "version " , row[0], ", number :", row[1]
    

cur.execute('''SELECT version, COUNT(version) AS nums
            FROM nodes
            WHERE (user="nmixter" or user = "mk408")
            GROUP BY version
            ORDER BY nums DESC
            limit 5
            ''')
output=cur.fetchall()
for row in output:
    print "version " , row[0], ", number :", row[1]
conn.commit()
conn.close()
# Out:
# version  1 , number : 244311
# version  2 , number : 5578
# version  3 , number : 992
# version  4 , number : 566
# version  5 , number : 399
# version  1 , number : 377882
# version  2 , number : 8908
# version  4 , number : 3009
# version  3 , number : 2228
# version  5 , number : 2087

# %% [markdown]
# # Contributor statistics
# ## overall
# + Top user "nmixter" contributed 19.78% of the data
# + Top five users contributed 47.20% of the data
# + Top ten users contributed 63.06% of the data
#
# #### we also want to know the contribution base on the version
# #### we find the first version that is most used version.
#
# ## base on version
# + Top user "nmixter" contribution is 24.63% in the first version
# + Top two users contribution is 38.01% in the first version

# %% [markdown]
# ## postcode check
# ##### we try to find out users input non digits into postcode

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute('''
            SELECT U.user
            FROM(
            SELECT way.user
            FROM ways_tags, way
            WHERE way.uid=ways_tags.id
            and ways_tags.key= "postcode"
            and ways_tags.value=""
            UNION ALL
            SELECT nodes.user
            FROM nodes_tags, nodes
            WHERE nodes.id=nodes_tags.id
            and nodes_tags.key="postcode"
            and nodes_tags.value='') U

            ''')
output=cur.fetchall()
print output



conn.commit()
conn.close()
# Out:
# [(u'n76_cupertino_import',)]

# %% [markdown]
# ## Top 5 City

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute(''' UPDATE ways_tags
                SET value='San Jose'
                WHERE type = "addr"
                and key="city" 
                and (value = "San jose" or value = "san jose" or value = "San Jos\xe9" )

            ''')
output=cur.fetchall()
cur.execute('''SELECT ways_tags.value, COUNT(ways_tags.value) AS count
                FROM ways_tags
                WHERE ways_tags.type = "addr"
                and ways_tags.key="city"
                GROUP BY ways_tags.value
                ORDER BY count DESC
                LIMIT 5
            ''')
output=cur.fetchall()
print "Top 5 city \n"
for row in output:
    print "City's name: " ,row[0], ";  count: ", row[1]

conn.commit()
conn.close()
# Out:
# Top 5 city
#
# City's name:  Sunnyvale ;  count:  663
# City's name:  San Jose ;  count:  475
# City's name:  Morgan Hill ;  count:  340
# City's name:  Santa Clara ;  count:  214
# City's name:  Saratoga ;  count:  183

# %% [markdown]
# ## Top 10 amenity in San Jose

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()
cur.execute('''
          SELECT value, COUNT(*) as num
            FROM nodes_tags
            WHERE key='amenity'
            GROUP BY value
            ORDER BY num DESC
            LIMIT 10; 
            ''')

    
cur.execute('''
          SELECT value, COUNT(*) as num
            FROM nodes_tags
            WHERE key='amenity'
            GROUP BY value
            ORDER BY num DESC
            LIMIT 10; 
            ''')

                        

output=cur.fetchall()
print "Top 5 amenity \n"
for row in output:
    print "amenity: " ,row[0], ";  count: ", row[1]
# Out:
# Top 5 amenity
#
# amenity:  restaurant ;  count:  740
# amenity:  fast_food ;  count:  354
# amenity:  cafe ;  count:  220
# amenity:  place_of_worship ;  count:  189
# amenity:  bench ;  count:  170
# amenity:  bicycle_parking ;  count:  166
# amenity:  school ;  count:  157
# amenity:  toilets ;  count:  142
# amenity:  fuel ;  count:  124
# amenity:  bank ;  count:  114

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

    
cur.execute('''
            SELECT nodes_tags.value, COUNT(*) as num
            FROM nodes_tags 
            JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value='fast_food') i
            ON nodes_tags.id=i.id
            WHERE nodes_tags.key='name'
            GROUP BY nodes_tags.value
            ORDER BY num DESC
            LIMIT 10;
            ''')

                        

output=cur.fetchall()
for row in output:
    print row[1], row[0]
# Out:
# 33 Subway
# 12 Taco Bell
# 10 McDonald's
# 8 Burger King
# 8 Panda Express
# 8 Togo's
# 7 Jamba Juice
# 7 KFC
# 6 Jack in the Box
# 5 Baskin-Robbins

# %% [markdown]
# ### Fast food in San Jose
# >we can see around 10% of Fast Food franchise is Subway. this is not a suprise because Subway is the largest franchise.

# %% [markdown]
# ######  San Jose has many good restaurant , we want to know what type of food

# %% [markdown]
# # restaurant group by cuisine

# %%
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

    
cur.execute('''
            SELECT nodes_tags.value, COUNT(*) as num
            FROM nodes_tags 
            JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value='restaurant') i
            ON nodes_tags.id=i.id
            WHERE nodes_tags.key='cuisine'
            GROUP BY nodes_tags.value
            ORDER BY num DESC
            LIMIT 10;
            ''')

                        

output=cur.fetchall()
for row in output:
    print row[1], " are", row[0], " cuisine"
# Out:
# 62  are chinese  cuisine
# 49  are vietnamese  cuisine
# 48  are mexican  cuisine
# 47  are pizza  cuisine
# 38  are japanese  cuisine
# 30  are indian  cuisine
# 27  are italian  cuisine
# 24  are thai  cuisine
# 22  are american  cuisine
# 19  are sushi  cuisine

# %% [markdown]
# ### Restaurant
# + Top 10 cuisine is only 48% of the restaurant.
# + we can say that San Jose very diverse in food.
#
# + we also want to know the name of those restaurant.

# %% [markdown]
# # restaurant name group by cuisine

# %%
restaurant=defaultdict(set)
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

    
cur.execute('''
            SELECT  name.value, cuisine.value
            
            FROM (SELECT id, value
                    FROM nodes_tags
                    WHERE id IN (SELECT id
                                FROM nodes_tags
                                WHERE value = "restaurant")
                    AND key = "cuisine") cuisine
            JOIN (SELECT id, value
                    FROM nodes_tags
                    WHERE id IN (SELECT id
                                FROM nodes_tags
                                WHERE value = "restaurant")
                    AND key = "name") name
            ON name.id = cuisine.id


            ''')

                        

output=cur.fetchall()

for row in output:
    restaurant[row[1]].add(row[0])
pprint (dict(restaurant))
conn.commit()
conn.close()
# Out:
# {u'Mediterranean,_wine_tasting, beer tasting, live music': set([u'Santorini Wine and Beer Garden']),
#  u'Persian': set([u'House of Kabobs']),
#  u'Traditional American': set([u"Vahl's Restaurant & Cocktail"]),
#  u'Vietnamese': set([u'Pho Spot', u'Pho Wagon']),
#  u'afgan': set([u'Kabul']),
#  u'american': set([u"Applebee's",
#                    u'Bill of Fare',
#                    u'Billy Berk\u2019s',
#                    u"Birk's Restaurant",
#                    u"Chili's Grill & Bar",
#                    u'Country Inn Cafe II',
#                    u'Denny\u2019s',
#                    u'Elephant Bar',
#                    u"Eric's Delli Cafe",
#                    u'Fahrenheit',
#                    u"Hobee's",
#                    u'IHOP',
#                    u"J.J. Magoo's Pizza",
#                    u"John's Cafe",
#                    u'Longhorn restaurant',
#                    u"Marie Callender's",
#                    u"Mimi's Cafe",
#                    u'Stacks',
#                    u"T.G.I. Friday's",
#                    u'Tarragon Restaurant',
#                    u"Tony Roma's",
#                    u'Viva']),
#  u'arab': set([u'Dishdash Middle Eastern Grill']),
#  u'asian': set([u'Food Court',
#                 u'Mango Garden',
#                 u'Merit Vegetarian Cuisine',
#                 u'Mosaic',
#                 u'SJ Omogari Korean Restaurant']),
#  u'bakery': set([u'Paris Baguette']),
#  u'barbecue': set([u"Armadillo Willy's",
#                    u"Sam's Bar-B-Que",
#                    u'Smoking Pig BBQ Company']),
#  u'brazilian': set([u'Fogo de Ch\xe3o']),
#  u'breakfast': set([u'Southern Kitchen']),
#  u'burger': set([u'Brown Chicken Brown Cow',
#                  u'Five Guys Bugers and Fries',
#                  u'Johnny Rockets',
#                  u"Mo's",
#                  u'Mooyah',
#                  u'Nom Burger',
#                  u'Red Robin',
#                  u'Rose Donuts and Cafe',
#                  u'San Jose Bar & Grill',
#                  u'SmashBurger',
#                  u"St John's Bar & Grill",
#                  u'The Burger Pit',
#                  u'The Habit Burger Grill',
#                  u'The Joint',
#                  u'Wayback Burgers']),
#  u'cajun': set([u'Crab & Cray']),
#  u'cambodian': set([u'Chez Sovan']),
#  u'caribbean': set([u'Back A Yard']),
#  u'chicken': set([u'Wing Stop']),
#  u'chinese': set([u'ABC Seafood Restaurant',
#                   u"Andy's Restaurant",
#                   u'Asia Village',
#                   u'Chef Ko',
#                   u'Chef Yu',
#                   u'Chili Garden',
#                   u'China Palace Restaurant',
#                   u'China Taste',
#                   u'Chinese Food Court',
#                   u'Classic Guilin Rice Noodles',
#                   u'Dalian Kitchen',
#                   u'Darda',
#                   u'Dynasty Chinese Seafood',
#                   u'Edna Ray',
#                   u'England Rose Garden',
#                   u'Famous Food Restaurant',
#                   u'Ginger Cafe',
#                   u'Great Vegi Land',
#                   u'Hana dumpling',
#                   u'Hong Fu',
#                   u'Hong Kong Saigon Seafood Harbor',
#                   u"Hong's Gourmet",
#                   u'House of Egg Rolls',
#                   u'JX Cuisine',
#                   u'Jade Cathay',
#                   u'Joy Luck Palace',
#                   u'Joy Wok',
#                   u'K-K Chinese Restaurant',
#                   u"Koong's Restaurant",
#                   u"Lan's Garden",
#                   u"Lee's Village",
#                   u'M Lounge',
#                   u"Ma Ma Chen's Kitchen",
#                   u'Mandarin Gourmet',
#                   u'Ming Tasty',
#                   u"Mr Chau's Chinese Fast Food",
#                   u'New Tung Kee',
#                   u'Noodle Talk',
#                   u"P.F. Chang's",
#                   u'P.F.Changs China Bistro',
#                   u'Palace Cafe',
#                   u'Panda Express',
#                   u'Pearl River',
#                   u'Peking House',
#                   u'Shanghai Dim Sim',
#                   u'Shanghai Ding Sheng Restaurant',
#                   u'Shanghai Flavor Shop',
#                   u'Shangri-La',
#                   u'Shaoshan Mountain',
#                   u'Taiwan',
#                   u'Taiwan Cafe',
#                   u'Tao Tao',
#                   u'The Porridge',
#                   u'Wenzhou',
#                   u'Wing\u2019s',
#                   u'Yong Shen',
#                   u'ai noodle',
#                   u'guan dong house',
#                   u'\u98df\u5168\u98df\u7f8e (Perfect Chinese Food)']),
#  u'chinese;vietnamese': set([u'Asian Express']),
#  u'coffee_shop': set([u"Jimmy's"]),
#  u'diner': set([u"Sara's Kitchen"]),
#  u'donuts': set([u'Daily Donuts', u'Krispy Kreme']),
#  u'ethiopian': set([u'Gojo;\u130e\u1306']),
#  u'falafel': set([u'Falafel Cafe']),
#  u'filipino': set([u'Barrio Fiesta']),
#  u'fish': set([u'Yankee Pier']),
#  u'fish_and_chips': set([u'Windsor Fish and Chips']),
#  u'french': set([u'La Maison du Cafe',
#                  u'La M\xe8re Michelle',
#                  u'Le Papillon']),
#  u'french;vietnamese': set([u'White Shallot']),
#  u'frozen_yogurt': set([u'Yogurtland']),
#  u'gastropub': set([u'Firehouse No. 1 Gastropub']),
#  u'german': set([u'Hardy\u2019s Bavaria', u'Teske\u2019s Germania']),
#  u'greek': set([u'Athena Grill',
#                 u'Nemea Greek Taverna',
#                 u'Opa',
#                 u'Opa!',
#                 u'Pita Pit',
#                 u'Taverna Bistro',
#                 u'Yiassoo Greek Specialties']),
#  u'hawaiian': set([u'Hawaiian Drive Inn', u'Hukilau San Jose']),
#  u'hot_dog': set([u'Supreme Dog']),
#  u'hotdog': set([u'Weinerschnitzel']),
#  u'ice_cream': set([u'Baskin-Robbins', u'Nirvanaah!', u'Pizza-my-Heart']),
#  u'indian': set([u'8Elements',
#                  u'Aasna, Melange of India',
#                  u'Amber India',
#                  u'Arka',
#                  u'Athidhi Indian Cuisine',
#                  u'Bombay Garden',
#                  u'Chaat House',
#                  u'Curry Bhavan',
#                  u'Dosa & Curry Cafe',
#                  u'Kaati Fresh',
#                  u'Komala Vilas',
#                  u"Kwality Sweets 'n Food",
#                  u'L&L Hawaiian BBQ',
#                  u'Little India Cafe',
#                  u'Madhuban Indian Cuisine',
#                  u'Madura Indian restaurant',
#                  u'Panchavati',
#                  u'Punjab Cafe',
#                  u'Rajjot Sweets and Snacks',
#                  u'Rasam\u2019s',
#                  u'Sagar Sweets',
#                  u'Shan Restaurant',
#                  u'Silver Spoon',
#                  u'Sneha',
#                  u'Spice Hut',
#                  u'Tandoori Bites',
#                  u'Tandoori Cafe',
#                  u'Tandoori Oven',
#                  u'Turmeric']),
#  u'international': set([u'Arya', u'Loving Hut', u'Zeytoun Restaurant']),
#  u'iranian': set([u'Chelokababi']),
#  u'irish,_pizza,_burger,_steak': set([u"C.B. Hannegan's"]),
#  u'italian': set([u'A Bellagio',
#                   u"Amici's East Coast Pizzeria",
#                   u'Bella Saratoga',
#                   u'Buca di Beppo',
#                   u'Da Mario',
#                   u'Florentine Trattoria',
#                   u'Florentines',
#                   u'Gardino',
#                   u"Giorgio's Italian Food & Pizzeria",
#                   u'Il Fornaio - WESTIN HOTEL',
#                   u'Il Postale',
#                   u'La Pastaia',
#                   u'La Pizzeria',
#                   u'Maggiano\u2019s Little Italy',
#                   u'Nick\u2019s Bistro Italian',
#                   u'Olive Garden',
#                   u'Original Joe\u2019s',
#                   u'Paesano Ristorante Italiano',
#                   u'Pasta Fresca',
#                   u'Pasta Pomodoro',
#                   u"Romano's Macaroni Grill",
#                   u'The Pasta Market',
#                   u'Tigelleria Organic Restaurant']),
#  u'jamaican': set([u'Reggae Pot Jamaican Restraurant']),
#  u'japanese': set([u'Almaden Sushi',
#                    u'Azuma Japanese Cuisine',
#                    u'Azuma Sushi',
#                    u'Ed\u2019s Teriyaki',
#                    u'Genji',
#                    u'Gombei Bento',
#                    u'Gyu-Kaku',
#                    u'Hachi Ju Hachi',
#                    u'Hoshi',
#                    u'Ichi Maru',
#                    u'Japanese Ramen',
#                    u'Kaita',
#                    u'Kamakura',
#                    u'Kumako Ramen',
#                    u'Masu Sushi',
#                    u'Men-Bei Ramen',
#                    u'Minato',
#                    u'Okayama',
#                    u'Orenchi',
#                    u'Ramen Taka',
#                    u'Rokko',
#                    u'Saizo',
#                    u'Senro Sushi',
#                    u'Seto',
#                    u'Seven Seas Sushi',
#                    u'Shaburi',
#                    u'Shiki',
#                    u'Sushi Club',
#                    u'Sushi Infinity',
#                    u'Sushi Kazoo',
#                    u'Tengu Sushi',
#                    u'Tonto',
#                    u'Yoshida Restaurant',
#                    u'Yoshinoya',
#                    u'Yuki Sushi',
#                    u'yatai sushi']),
#  u'kebab': set([u'Off The Stick']),
#  u'korean': set([u'Jang Su Jang',
#                  u'Jang Tu',
#                  u'K.zzang',
#                  u'Kong Tofu and BBQ',
#                  u'Kunjip Restaurant',
#                  u'Ohgane',
#                  u'Roundtable pizza']),
#  u'korean_BBQ': set([u'Gen Korean BBQ']),
#  u'latin_american': set([u'Palacio']),
#  u'malaysian': set([u'New Penang Garden']),
#  u'mediterranean': set([u'Agape Grill',
#                         u"Bella's Bar & Grill",
#                         u'Cafe Eden',
#                         u'Dish Dash',
#                         u'Falafel Bite',
#                         u'Falafel Drive In',
#                         u'Obed',
#                         u"Robee's Falafel",
#                         u'SAJJ',
#                         u'Sunnyvale Cafe']),
#  u'mexican': set([u'Andal\xe9',
#                   u'Angelou\u2019s Taqueria',
#                   u'Aqui',
#                   u'Burrito Factory',
#                   u'Casa de Cobre',
#                   u'Casa lopez',
#                   u'Checo\u2019s',
#                   u'Chipotle',
#                   u'Chipotle Mexican Grill',
#                   u'Consuelo Mexican Bistro',
#                   u'Dona Maria',
#                   u'El Amigo',
#                   u'El Capucho',
#                   u'El Gallo Giro',
#                   u"Garcia's Taqueria",
#                   u'Hot Tamales',
#                   u'La Arenita',
#                   u'La Costa',
#                   u'La Milpa',
#                   u'La Victoria Taqueria',
#                   u'Las Flamas',
#                   u'Las Islitas',
#                   u'Little Michoacan Taqueria',
#                   u'Mango\u2019s',
#                   u'Mexicali Grill',
#                   u'Mezcal',
#                   u'Mi Tierra',
#                   u'Muchos!',
#                   u'Puerto Azul',
#                   u"Roberto's Cantina",
#                   u"Rubio's",
#                   u"Ruby's Taqueria",
#                   u'Se\xf1or Jalepe\xf1o',
#                   u'Se\xf1or Taco',
#                   u'Sinaloa Restaurant',
#                   u'Tacomania',
#                   u'Tacos Al Carbon',
#                   u'Taqueria La Victoria',
#                   u'Tia Juana Grill',
#                   u'Tres Gringos',
#                   u'Tres Potrillos',
#                   u'Una Mas Mexican Grill',
#                   u'Zona Rosa']),
#  u'middle eastern': set([u'Cafe Falafel']),
#  u'middle_eastern': set([u"Robee's Falafel"]),
#  u'persian': set([u'Piccolo', u'Rose Intl. Market']),
#  u'pho': set([u'PhoEver']),
#  u'pizza': set([u'Amato Pizza',
#                 u'Amici\u2019s',
#                 u'Blue Line Pizza',
#                 u'California Pizza Kitchen',
#                 u"Chuck E. Cheese's",
#                 u"Domino's",
#                 u'Fast Pizza',
#                 u'Grande Pizzeria',
#                 u"Jake's Pizza",
#                 u'Legends Pizza',
#                 u'MOD Pizza',
#                 u'Mod Pizza',
#                 u"Mountain Mike's Pizza",
#                 u"Papa John's",
#                 u"Patxi's",
#                 u'Pizza Antica',
#                 u'Pizza California',
#                 u'Pizza Chicago',
#                 u'Pizza Hut',
#                 u'Pizza My Heart',
#                 u'Pizz\u2019a Chicago',
#                 u'Premier Pizza',
#                 u'Rosie\u2019s New York Pizza',
#                 u'Round Table',
#                 u'Round Table Pizza',
#                 u'Roundtable pizza',
#                 u"Sal's Pizza",
#                 u'San Carlos Pizza',
#                 u'Tony Di Maggios Pizza',
#                 u"Vito's Famous Pizza",
#                 u'Willow Street Pizza',
#                 u'ciceros pizza']),
#  u'portuguese': set([u'Bacalhau Grill']),
#  u'ramen': set([u'Myzen']),
#  u'regional': set([u'Cupertino Bakery',
#                    u'Fresh Choice',
#                    u"Hobee's",
#                    u'Hot breads',
#                    u"Hult's"]),
#  u'sandwich': set([u'Beach Hut Deli',
#                    u"Erik's DeliCafe",
#                    u"Erik's DeliCaf\xe9",
#                    u'Erik\u2019s DeliCaf\xe9',
#                    u'Fresh U Order',
#                    u"Ike's Place",
#                    u"Lee's Sandwiches",
#                    u'Lettuce Sandwich Shop',
#                    u'Lunch with Tony',
#                    u'Panera Bread',
#                    u'Subway',
#                    u"Togo's"]),
#  u'sandwich,_breakfast,_salads, lunch, brunch': set([u'Bell Tower Bistro & Patisserie']),
#  u'seafood': set([u'Fish Market',
#                   u'Scott\u2019s Seafood',
#                   u'The Boiling Crab']),
#  u'seafood,_sports_bar': set([u'Blue Water']),
#  u'spanish': set([u'Picasso\u2019s Tapas']),
#  u'steak_house': set([u"Alexander's",
#                       u'Black Angus',
#                       u'Henry\u2019s Hi-Life',
#                       u'LB Steak',
#                       u'Taurinus',
#                       u'The Cats',
#                       u"Vaquero's",
#                       u'Yard House San Jose']),
#  u'sushi': set([u'Bluefin',
#                 u'Cherry Sushi',
#                 u'CreAsian Japanese Cuisine',
#                 u'Fuji',
#                 u'Hana Sushi',
#                 u'Kazoo',
#                 u'Ozu',
#                 u'Restaurant Tsugaru',
#                 u'Sushi Blvd',
#                 u'Sushi Confidential',
#                 u'Sushi Expo',
#                 u'Sushi Express',
#                 u'Sushi Hana',
#                 u'Sushi Maru',
#                 u'Sushi O Sushi',
#                 u'Sushi on the Run',
#                 u'Tatami Sushi & Seafood Buffet',
#                 u'Tomo Sushi',
#                 u'yo yo sushi']),
#  u'taiwanese': set([u'red hot wok']),
#  u'thai': set([u'Amarin',
#                u'Amarin Thai Cuisine',
#                u'Bai Tong',
#                u'Banana Leaf',
#                u'Bangkok Boulevard',
#                u'Barn Thai',
#                u'Bistro Siam',
#                u'Blue Mango',
#                u'Dusita Thai Cuisine',
#                u'Erawan Thai Cuisine',
#                u'Hanuman',
#                u'Pad Thai Cusine',
#                u'Rama V Thai Cuisine',
#                u'Sa-by Thai',
#                u'Siam Taste',
#                u'Siam Thai',
#                u'Thai Basil',
#                u'Thai Cafe',
#                u'Thai Chili Cuisine',
#                u'Thai Spice',
#                u'Thai Spoons',
#                u'Thai pepper cuisine',
#                u'White Elephant']),
#  u'thai_fusion': set([u'Mint Leaf']),
#  u'vegetarian': set([u'Veggie Grill']),
#  u'vietnamese': set([u'A & K Noodle House',
#                      u'Beef Noodle #1',
#                      u'B\xe1nh Canh 3 mien',
#                      u'B\xe1nh Cu\u1ed1n T\xe2y H\u1ed3 #8',
#                      u'B\xe1nh X\xe8o Nha Trang',
#                      u'B\xecnh D\xe2n Qu\xe1n',
#                      u'B\xfan B\xf2 Hu\u1ebf',
#                      u'B\xfan B\xf2 Hu\u1ebf San Jose',
#                      u'C\u01a1m T\u1ea5m Thi\xean H\u01b0\u01a1ng',
#                      u'Dac Phuc',
#                      u'Dakao',
#                      u'Fast-n-Fresh',
#                      u'Hanna',
#                      u'Jade Leaf',
#                      u"Lee's Sandwiches",
#                      u'Little Saigon Pho',
#                      u'L\xf2 B\xe1nh cu\u1ed1n Thanh Tr\xec',
#                      u'Nha Trang',
#                      u'On a Roll',
#                      u'Paloma',
#                      u'Pho 101',
#                      u'Pho Khang',
#                      u'Pho Lynn',
#                      u'Pho Vy',
#                      u'Pho Wagon',
#                      u'Phuong Thao Vietnamese Restaurant',
#                      u'Ph\u1edf H\xe0',
#                      u'Ph\u1edf H\xf2a',
#                      u'Ph\u1edf Nam - Pho Nam',
#                      u'Ph\u1edf T\xe0u Bay',
#                      u'Ph\u1edf Vi\u1ec7t',
#                      u'Ph\u1edf \xdd #1',
#                      u'Saigon Kitchen',
#                      u'Tay Do',
#                      u'Thanh Lan',
#                      u'Thanh S\u01a1n Tofu',
#                      u'Thi\xean H\u01b0\u01a1ng',
#                      u'Tofoo C\u01a1m Chay',
#                      u'\u1ed0c C\xe2y D\u1eeba']),
#  u'vietnamnese': set([u'Cam Hung sandwich & Coffee'])}

# %% [markdown]
# ## Conclusion
# > After looking at the result, we can see half of the data set is getting input by only few users, the good thing about that is the format of the data is not too different, and users who can insert large amount of data is people who understand the open street map really well speically on the version one. For new users want to contribute to the data set, they should find those contrubute the most and learn from them.
#
# #### suggestion
# >open street map should prove a guildline for new users, teach the way to input data in the same way,such as capital letter, abbreviation. Gives example about how to break down the data into different field. Some users put all the address in one field and some break it down to street, city , state. Open street map should give a guildline about how to insert the data, so it will be easier for people to use the data set.
#
# >we also notice that many of the tag type only have one or two data. If the open street map should limit or only let people choose from a list of item, people do not need to create different tags key or tags type. This will make people want to analysis the data easier and do not have to many confusion about different type that users create on there own.
